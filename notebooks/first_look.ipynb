# %%
import skimage
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mpc
import utils
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\joelw\\OneDrive\\Documents\\Projects\\Programming\\Elastic-Deformation\\notebooks\\utils.py'>

# %%
image = skimage.data.coffee()

# %%
plt.imshow(image)

# %%
T = utils.ElasticDeformation2D(np.random.RandomState(0), alpha = 4000)
image_ = T(image.transpose([2,0, 1])).transpose([1,2,0])

# %%
fig, axs = plt.subplots(1,2)
axs[0].imshow(image)
axs[1].imshow(image_)
fig.set_size_inches(10,15)

# %%
output = T.call_verbose(image.transpose([2,0, 1]))

# %%
output.keys()
image_shape = output['image_shape']
dx = output['dx']
dy = output['dy']
x_ = output['x+dx']
y_ = output['y+dy']
image_ = output['m_']

# %%
dz = utils.vector_2_rgb(dx,dy)

# %%
r = np.sqrt(np.power(dx,2)+np.power(dy,2))

# %%
plt.imshow(dz)

# %%
from PIL import Image

im = Image.fromarray(image)
im_ = Image.fromarray(image_.transpose([1,2,0]))
vec = Image.fromarray((dz*255).astype('uint8'))

# %%
aa = Image.blend(im, im_, alpha = 0.5)
plt.imshow(np.asarray(aa))

# %%
com = Image.blend(im, vec, alpha = 0.9)
com_ = Image.blend(im_, vec, alpha = 0.9)
com_aa = Image.blend(aa, vec, alpha = 0.7)

# %%
fig, axs = plt.subplots(1,2)
axs[0].imshow(np.asarray(vec))
axs[1].imshow(np.asarray(com_aa))
fig.set_size_inches(15,15)

# %%
hue = np.angle(dz)
sat = np.absolute(dz)
lig = 1/2 * np.ones_like(sat)
image_hsv = np.stack((hue, sat,lig), axis = 0)

# %%
importlib.reload(utils)
m = utils.get_hue_image((360,100))
plt.imshow(m.transpose([0,1,2]))

# %%
m[:,:,b]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10560/343205473.py in <module>
# ----> 1 m[:,:,b]
#
# NameError: name 'b' is not defined

# %%
image.shape
# Out:
# (400, 600, 3)
